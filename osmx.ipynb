# %% [markdown]
# <a href="https://colab.research.google.com/github/mgamzec/GeospatialData-Python/blob/main/osmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx

# %%
import osmnx as ox

# %%
#city = ox.geocode_to_gdf('Antalya, Turkey')
city=ox.geocode_to_gdf('Antalya,Turkey') #city,country
#ax = ox.project_gdf(city).plot()
ax=ox.project_gdf(city).plot()
_ = ax.axis('off')

# %%
ox.plot_graph(ox.graph_from_place('Antalya, Turkey'))
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
